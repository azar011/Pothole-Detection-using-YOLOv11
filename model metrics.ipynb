# %%
import os

paths = [
    "D:/pothole detection/dataset_format/train/images",
    "D:/pothole detection/dataset_format/valid/images",
    "D:/pothole detection/dataset_format/test/images"
]

for path in paths:
    print(f"Checking {path}: {'Exists' if os.path.exists(path) else 'Missing'}")
# Out:
# Checking D:/pothole detection/dataset_format/train/images: Exists
# Checking D:/pothole detection/dataset_format/valid/images: Exists
# Checking D:/pothole detection/dataset_format/test/images: Exists

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("Weights/best.pt")

# Run validation on your dataset
metrics = model.val(data="D:/pothole detection/dataset_format/dataset.yaml", imgsz=640, conf=0.3)

# Print results
print(metrics)
# Out:
# Ultralytics 8.3.71  Python-3.12.4 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning D:\pothole detection\dataset_format\valid\labels.cache... 1808 images, 0 backgrounds, 0 corrupt: 100%|███
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 113/113 [05:
#                    all       1808       4487      0.917      0.776      0.873      0.724
# Speed: 2.8ms preprocess, 184.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs\detect\val7
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000002218412DD60>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...
